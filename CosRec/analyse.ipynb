# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %%
def print_styling(figsize=(10,8)):
    plt.rc('figure', figsize=figsize) 
    plt.style.use("seaborn")
    sns.set_palette("dark")
    SMALL_SIZE = 15
    MEDIUM_SIZE = 18
    BIGGER_SIZE = 26

    plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
    plt.rc('lines', linewidth=2)

    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    
    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
def plot_curve(df,x = "SCALE", y = "s_mean", ax=None, mode = "sklearn", titel = "R2-Score", SaveName = False):
    if ax==None:
        ax = plt.gca()
    plt.sca(ax)

    plt.semilogy(df[x], df[y], label = mode, marker='x')

    plt.grid(True)
    plt.legend()
    plt.xlabel("n_iter")
    plt.suptitle(titel)
    if "time" in y:
        plt.ylabel("time [s]")
    else:
        plt.ylabel(y)
    if SaveName:
        plt.savefig(SaveName)

# %%
mpl.style.use('seaborn')
plt.figure(figsize=(10,8))
print_styling()
plot_curve(df,x = "Epoch", y = "loss", mode="ml1m",titel = "learning-curve")
plt.savefig("out/Learning_Curve_ml1m")

# %%
df = pd.read_csv("results/ml1m", index_col=None, header=0,sep=",")

# %%
df
# Out:
#    Epoch      loss       map    prec@1   prec@10    prec@5  recall@1  \
# 0    1.0  0.784027  0.111016  0.201987  0.153626  0.170629  0.010298
# 1    2.0  0.578749  0.135674  0.243212  0.188576  0.210033  0.013422
# 2    3.0  0.516116  0.147036  0.253974  0.201887  0.221821  0.013537
# 3    4.0  0.480564  0.158031  0.272351  0.216490  0.239669  0.014889
# 4    5.0  0.455199  0.161181  0.279636  0.219752  0.243444  0.015007
# 5    6.0  0.436303  0.168031  0.284272  0.227020  0.250232  0.016601
# 6    7.0  0.422295  0.174948  0.305629  0.235497  0.263808  0.017746
# 7    8.0  0.412431  0.177076  0.307947  0.236507  0.265795  0.018267
# 8    9.0  0.401272  0.177964  0.303146  0.235497  0.262682  0.017929
# 9   10.0  0.394555  0.183460  0.311258  0.242897  0.271523  0.018296
#
#    recall@10  recall@5       time1       time2
# 0   0.074789  0.042970  119.205884  140.047163
# 1   0.094187  0.053770  119.204272  142.650879
# 2   0.102357  0.057582  120.939455  141.933112
# ...

# %%
plt.plot(df["loss"])
